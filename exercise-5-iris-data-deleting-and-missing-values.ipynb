# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %%
pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",sep=',')
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
iris=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",sep=',')
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

# %%
list1=['sepal_length (in cm)','sepal_width (in cm)','petal_length (in cm)','petal_width (in cm)','class']
list1
# Out:
# ['sepal_length (in cm)',
#  'sepal_width (in cm)',
#  'petal_length (in cm)',
#  'petal_width (in cm)',
#  'class']

# %%
iris.columns=list1
iris.head()
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   4.9                  3.0                   1.4
# 1                   4.7                  3.2                   1.3
# 2                   4.6                  3.1                   1.5
# 3                   5.0                  3.6                   1.4
# 4                   5.4                  3.9                   1.7
#
#    petal_width (in cm)        class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.4  Iris-setosa

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
iris.isnull().sum()
# Out:
# sepal_length (in cm)    0
# sepal_width (in cm)     0
# petal_length (in cm)    0
# petal_width (in cm)     0
# class                   0
# dtype: int64

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
#1st Method
iris['petal_length (in cm)'][10:30] = np.nan
# Out:
# /tmp/ipykernel_32/2172142831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iris['petal_length (in cm)'][10:30] = np.nan

# %%
iris.iloc[10:30]
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 10                   4.8                  3.4                   NaN
# 11                   4.8                  3.0                   NaN
# 12                   4.3                  3.0                   NaN
# 13                   5.8                  4.0                   NaN
# 14                   5.7                  4.4                   NaN
# 15                   5.4                  3.9                   NaN
# 16                   5.1                  3.5                   NaN
# 17                   5.7                  3.8                   NaN
# 18                   5.1                  3.8                   NaN
# 19                   5.4                  3.4                   NaN
# 20                   5.1                  3.7                   NaN
# 21                   4.6                  3.6                   NaN
# 22                   5.1                  3.3                   NaN
# ...

# %%
#2nd Method
iris.iloc[10:30,2]=np.nan
iris.iloc[10:30,0:5]
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 10                   4.8                  3.4                   NaN
# 11                   4.8                  3.0                   NaN
# 12                   4.3                  3.0                   NaN
# 13                   5.8                  4.0                   NaN
# 14                   5.7                  4.4                   NaN
# 15                   5.4                  3.9                   NaN
# 16                   5.1                  3.5                   NaN
# 17                   5.7                  3.8                   NaN
# 18                   5.1                  3.8                   NaN
# 19                   5.4                  3.4                   NaN
# 20                   5.1                  3.7                   NaN
# 21                   4.6                  3.6                   NaN
# 22                   5.1                  3.3                   NaN
# ...

# %%
iris.isna().sum()
# Out:
# sepal_length (in cm)     0
# sepal_width (in cm)      0
# petal_length (in cm)    20
# petal_width (in cm)      0
# class                    0
# dtype: int64

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris.iloc[10:30,2].fillna(1.0,inplace = True)
iris.iloc[10:30,0:5]
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 10                   4.8                  3.4                   1.0
# 11                   4.8                  3.0                   1.0
# 12                   4.3                  3.0                   1.0
# 13                   5.8                  4.0                   1.0
# 14                   5.7                  4.4                   1.0
# 15                   5.4                  3.9                   1.0
# 16                   5.1                  3.5                   1.0
# 17                   5.7                  3.8                   1.0
# 18                   5.1                  3.8                   1.0
# 19                   5.4                  3.4                   1.0
# 20                   5.1                  3.7                   1.0
# 21                   4.6                  3.6                   1.0
# 22                   5.1                  3.3                   1.0
# ...

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
iris.drop(labels='class', axis=1)
# Out:
#      sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                     4.9                  3.0                   1.4
# 1                     4.7                  3.2                   1.3
# 2                     4.6                  3.1                   1.5
# 3                     5.0                  3.6                   1.4
# 4                     5.4                  3.9                   1.7
# ..                    ...                  ...                   ...
# 144                   6.7                  3.0                   5.2
# 145                   6.3                  2.5                   5.0
# 146                   6.5                  3.0                   5.2
# 147                   6.2                  3.4                   5.4
# 148                   5.9                  3.0                   5.1
#
#      petal_width (in cm)
# 0                    0.2
# 1                    0.2
# 2                    0.2
# 3                    0.2
# ...

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.iloc[0:3,:]=np.nan
iris.iloc[0:3,:]
# Out:
#    sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
#
#    petal_width (in cm) class
# 0                  NaN   NaN
# 1                  NaN   NaN
# 2                  NaN   NaN

# %%
iris.isna().sum()
# Out:
# sepal_length (in cm)    3
# sepal_width (in cm)     3
# petal_length (in cm)    3
# petal_width (in cm)     3
# class                   3
# dtype: int64

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris=iris.dropna(axis = 0, how = "any")
iris.head(10)
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 3                    5.0                  3.6                   1.4
# 4                    5.4                  3.9                   1.7
# 5                    4.6                  3.4                   1.4
# 6                    5.0                  3.4                   1.5
# 7                    4.4                  2.9                   1.4
# 8                    4.9                  3.1                   1.5
# 9                    5.4                  3.7                   1.5
# 10                   4.8                  3.4                   1.0
# 11                   4.8                  3.0                   1.0
# 12                   4.3                  3.0                   1.0
#
#     petal_width (in cm)        class
# 3                   0.2  Iris-setosa
# 4                   0.4  Iris-setosa
# 5                   0.3  Iris-setosa
# 6                   0.2  Iris-setosa
# ...

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris = iris.reset_index(drop = True)
iris.head(100)
# Out:
#     sepal_length (in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                    5.0                  3.6                   1.4
# 1                    5.4                  3.9                   1.7
# 2                    4.6                  3.4                   1.4
# 3                    5.0                  3.4                   1.5
# 4                    4.4                  2.9                   1.4
# ..                   ...                  ...                   ...
# 95                   5.7                  2.8                   4.1
# 96                   6.3                  3.3                   6.0
# 97                   5.8                  2.7                   5.1
# 98                   7.1                  3.0                   5.9
# 99                   6.3                  2.9                   5.6
#
#     petal_width (in cm)            class
# 0                   0.2      Iris-setosa
# 1                   0.4      Iris-setosa
# ...

# %% [markdown]
# ### BONUS: Create your own question and answer it.
